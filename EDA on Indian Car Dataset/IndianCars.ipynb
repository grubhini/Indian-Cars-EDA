# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cars_ds_final.csv')
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
df.isnull().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
sns.heatmap(df.isnull(),cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
for c in df.columns:
  if(df[c].isnull().sum()>625):
    df.drop(columns=[c],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Key_Off_Reminder USB_Compatibility Infotainment_Screen  \
# ...

# %%
df.isnull().sum()
# Out:
# Make                       75
# Model                       0
# Variant                     0
# Ex-Showroom_Price           0
# Displacement               12
#                          ...
# Seat_Height_Adjustment    326
# Navigation_System         593
# Second_Row_AC_Vents       602
# Rear_Center_Armrest       559
# Turbocharger              618
# Length: 97, dtype: int64

# %%
for c in df.columns:
  unique=df[c].nunique()
  print(f'{c}:{unique}')
  if(unique==1):
    df.drop(columns=[c],inplace=True,axis=1)
  if(unique==df.shape[0]):
    df.drop(columns=[c],inplace=True,axis=1)
# Out:
# Make:39
# Model:263
# Variant:1064
# Ex-Showroom_Price:1179
# Displacement:129
# Cylinders:9
# Valves_Per_Cylinder:8
# Drivetrain:4
# Cylinder_Configuration:4
# Emission_Norm:4
# Engine_Location:7
# Fuel_System:2
# Fuel_Tank_Capacity:63
# Fuel_Type:6
# Height:211
# Length:228
# Width:182
# Body_Type:17
# Doors:4
# City_Mileage:164
# ARAI_Certified_Mileage:281
# Kerb_Weight:336
# Gears:8
# Ground_Clearance:73
# Front_Brakes:3
# Rear_Brakes:3
# Front_Suspension:140
# Rear_Suspension:173
# Front_Tyre_&_Rim:234
# Rear_Tyre_&_Rim:241
# Power_Steering:5
# Power_Windows:2
# Keyless_Entry:5
# Power:372
# Torque:342
# Odometer:4
# Speedometer:5
# Tachometer:7
# Tripmeter:4
# Seating_Capacity:8
# Seats_Material:4
# Type:5
# Wheelbase:153
# Wheels_Size:209
# 12v_Power_Outlet:5
# Audiosystem:8
# Aux-in_Compatibility:1
# Average_Fuel_Consumption:1
# Basic_Warranty:28
# Bluetooth:1
# Boot-lid_Opener:12
# Boot_Space:138
# CD_/_MP3_/_DVD_Player:1
# Central_Locking:1
# Child_Safety_Locks:1
# Clock:4
# ...

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Adjustable_Headrests Gross_Vehicle_Weight Airbags  \
# ...

# %%
for c in df.columns:
  print(f'{c}:{df[c].dtype}:{df[c].isnull().sum()}')
# Out:
# Make:object:75
# Model:object:0
# Variant:object:0
# Ex-Showroom_Price:object:0
# Displacement:object:12
# Cylinders:float64:66
# Valves_Per_Cylinder:float64:102
# Drivetrain:object:7
# Cylinder_Configuration:object:13
# Emission_Norm:object:11
# Engine_Location:object:43
# Fuel_System:object:8
# Fuel_Tank_Capacity:object:69
# Fuel_Type:object:0
# Height:object:1
# Length:object:0
# Width:object:12
# Body_Type:object:6
# Doors:float64:4
# City_Mileage:object:555
# ARAI_Certified_Mileage:object:114
# Kerb_Weight:object:365
# Gears:object:105
# Ground_Clearance:object:289
# Front_Brakes:object:25
# Rear_Brakes:object:25
# Front_Suspension:object:59
# Rear_Suspension:object:46
# Front_Tyre_&_Rim:object:49
# Rear_Tyre_&_Rim:object:48
# Power_Steering:object:57
# Power_Windows:object:97
# Keyless_Entry:object:274
# Power:object:0
# Torque:object:2
# Odometer:object:43
# Speedometer:object:45
# Tachometer:object:13
# Tripmeter:object:60
# Seating_Capacity:float64:6
# ...

# %%
new_df=df.copy()

# %%
df=new_df.copy()

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df['Ex-Showroom_Price']=df['Ex-Showroom_Price'].str.replace('Rs. ','')
df['Ex-Showroom_Price']=df['Ex-Showroom_Price'].str.replace(',','').astype(int)
# Out:
# <ipython-input-14-ffe41e4b46ca>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Ex-Showroom_Price']=df['Ex-Showroom_Price'].str.replace('Rs. ','')

# %%
df['Ex-Showroom_Price']
# Out:
# 0        292667
# 1        236447
# 2        296661
# 3        334768
# 4        272223
#          ...
# 1271    1302000
# 1272    1421000
# 1273    1431000
# 1274    1201000
# 1275    6862560
# Name: Ex-Showroom_Price, Length: 1267, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    Make      Model  Variant  Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt             292667       624 cc        2.0
# 1  Tata  Nano Genx       Xe             236447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm             296661       624 cc        2.0
# 3  Tata  Nano Genx      Xta             334768       624 cc        2.0
# 4  Tata  Nano Genx       Xm             272223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Adjustable_Headrests Gross_Vehicle_Weight Airbags  \
# ...

# %%
row_index=df.index[df['Make'].isnull()].tolist()
print(row_index)
# Out:
# [252, 253, 254, 255, 256, 257, 258, 303, 307, 308, 309, 310, 311, 322, 323, 324, 328, 329, 334, 335, 340, 349, 350, 351, 353, 354, 784, 785, 786, 787, 788, 789, 790, 791, 797, 800, 801, 802, 812, 850, 851, 852, 853, 870, 871, 874, 875, 876, 877, 878, 879, 880, 881, 882, 1016, 1017, 1024, 1025, 1026, 1027, 1028, 1029, 1038, 1039, 1040, 1137, 1138, 1139, 1140, 1141, 1142, 1210, 1211, 1242, 1243]

# %%
for i in row_index:
  df['Make'].iloc[i]=df['Model'].iloc[i].split()[0]
# Out:
# <ipython-input-19-cc848ba5c9d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Make'].iloc[i]=df['Model'].iloc[i].split()[0]

# %%
df.iloc[252]
# Out:
# Make                                              Mercedes-Benz
# Model                                     Mercedes-Benz B-Class
# Variant                                             B 180 Sport
# Ex-Showroom_Price                                       2988311
# Displacement                                            1595 cc
#                                              ...
# Parking_Assistance                     Rear sensors with camera
# Infotainment_Screen                             Touch Sensitive
# Multifunction_Steering_Wheel       Multifunction Steering Wheel
# Seat_Height_Adjustment          Electric Adjustment with Memory
# Rear_Center_Armrest                                 Cup Holders
# Name: 252, Length: 71, dtype: object

# %%
df['Make'].replace('Go+','Datsun',inplace=True)

# %%
df.iloc[875]
# Out:
# Make                                       Datsun
# Model                                         Go+
# Variant                                  Datsun T
# Ex-Showroom_Price                          552656
# Displacement                              1198 cc
#                                       ...
# Parking_Assistance                   Rear sensors
# Infotainment_Screen               Touch Sensitive
# Multifunction_Steering_Wheel                  NaN
# Seat_Height_Adjustment          Manual Adjustment
# Rear_Center_Armrest                           NaN
# Name: 875, Length: 71, dtype: object

# %% [markdown]
# ###Converting the fields into appropriate data types

# %%
new_df.drop_duplicates(keep='first',inplace=True)

# %%
for c in ['Height','Length','Width']:
  df[c]=new_df[c]

# %%
for c in ['Height','Length','Width']:
  df[c]=df[c].str.replace(' mm','')
  df[c]=pd.to_numeric(df[c],errors='raise')

# %% [markdown]
# ###Descriptive Statistics of numeric datatypes
#
# Numeric datatypes: ShowRoom prices, height,length, width

# %%
for c in ['Ex-Showroom_Price','Height','Length','Width']:
  print(df[c].describe())
# Out:
# count    1.267000e+03
# mean     4.617330e+06
# std      1.218793e+07
# min      2.364470e+05
# 25%      7.405535e+05
# 50%      1.055000e+06
# 75%      2.991400e+06
# max      2.121554e+08
# Name: Ex-Showroom_Price, dtype: float64
# count    1257.000000
# mean     1590.071476
# std       157.764609
# min         1.845000
# 25%      1495.000000
# 50%      1557.000000
# 75%      1665.000000
# max      2670.000000
# Name: Height, dtype: float64
# count    1258.000000
# mean     4293.432941
# std       478.943435
# min         4.640000
# 25%      3990.000000
# 50%      4324.000000
# 75%      4620.000000
# max      6092.000000
# Name: Length, dtype: float64
# count    1246.000000
# mean     1788.348993
# std       151.569335
# min         1.845000
# 25%      1699.000000
# 50%      1770.000000
# 75%      1850.000000
# max      2226.000000
# Name: Width, dtype: float64

# %% [markdown]
# ###Histograms to visualise numerical data (Prices)

# %%
sns.histplot(df['Ex-Showroom_Price'])
# Out:
# <Axes: xlabel='Ex-Showroom_Price', ylabel='Count'>

# %%
sns.kdeplot(df['Doors'])
# Out:
# <Axes: xlabel='Doors', ylabel='Density'>

# %% [markdown]
# ###Bar plots for categorical data

# %%
data=df['Make'].value_counts().rename_axis('Make').to_frame('Count')

# %%
data.size
# Out:
# 41

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.reset_index(inplace=True)

# %%
plot=sns.barplot(data,x='Make',y='Count')
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Maruti Suzuki'),
#  Text(1, 0, 'Hyundai'),
#  Text(2, 0, 'Mahindra'),
#  Text(3, 0, 'Tata'),
#  Text(4, 0, 'Toyota'),
#  Text(5, 0, 'Honda'),
#  Text(6, 0, 'Mercedes-Benz'),
#  Text(7, 0, 'Ford'),
#  Text(8, 0, 'Skoda'),
#  Text(9, 0, 'Bmw'),
#  Text(10, 0, 'Renault'),
#  Text(11, 0, 'Volkswagen'),
#  Text(12, 0, 'Audi'),
#  Text(13, 0, 'Nissan'),
#  Text(14, 0, 'Jeep'),
#  Text(15, 0, 'Land Rover Rover'),
#  Text(16, 0, 'Datsun'),
#  Text(17, 0, 'Fiat'),
#  Text(18, 0, 'Jaguar'),
#  Text(19, 0, 'Kia'),
#  Text(20, 0, 'Volvo'),
#  Text(21, 0, 'Maruti Suzuki R'),
#  Text(22, 0, 'Porsche'),
#  Text(23, 0, 'Lamborghini'),
#  Text(24, 0, 'Mg'),
#  Text(25, 0, 'Icml'),
#  Text(26, 0, 'Mini'),
#  Text(27, 0, 'Lexus'),
#  Text(28, 0, 'Land Rover'),
#  Text(29, 0, 'Maserati'),
#  Text(30, 0, 'Rolls-Royce'),
#  Text(31, 0, 'Ferrari'),
#  Text(32, 0, 'Mitsubishi'),
#  Text(33, 0, 'Bentley'),
#  Text(34, 0, 'Force'),
#  Text(35, 0, 'Premier'),
#  Text(36, 0, 'Isuzu'),
# ...

# %% [markdown]
# ###Box plot to identify the outliers in the data

# %%
plot=sns.boxplot(data=df,x='Length')

# %%
plot=sns.boxplot(data=df,x='Width')

# %%
import plotly.express as px
plot=px.pie(data,names='Make',values='Count')

# %%
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Bivariate Analysis

# %%
sns.heatmap(df.corr(),cmap='Blues')
# Out:
# <ipython-input-38-b350443d6043>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %% [markdown]
# From the above correlation matrix, we make the following insights:
#
# 1.No of cylinders and Prices are directly related.
#
# 2.Length and the width are strongly related to each other.
#
# 3.Length and the number of airbags

# %% [markdown]
# ###Plot scatter plots to explore the relationship between two numeric variables (e.g., sales vs. price).

# %%
df['Count']=1

# %%
d1=df.groupby(['Make']).sum().rename_axis('Make').reset_index(drop=True)
d1.head()
# Out:
# <ipython-input-40-067d404f95b4>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#    Ex-Showroom_Price  Cylinders  Valves_Per_Cylinder   Height     Length  \
# 0          108802326       32.0                 12.0   4794.0   14233.00
# 1          224453350      160.0                140.0  45030.0  143308.00
# 2             546000        0.0                  2.0   3304.0    5504.00
# 3          243395126       64.0                 24.0   9622.0   29871.00
# 4          305480000      202.0                148.0  59482.0  172810.64
#
#        Width  Doors  Seating_Capacity  Number_of_Airbags  Count
# 0   6179.000    8.0               8.0               22.0      3
# 1  56080.000  131.0             161.0              235.0     31
# 2   2624.000    8.0               8.0                0.0      2
# ...

# %%
d1['Avg']=d1['Ex-Showroom_Price']/d1['Count']
d1.head()
# Out:
#    Ex-Showroom_Price  Cylinders  Valves_Per_Cylinder   Height     Length  \
# 0          108802326       32.0                 12.0   4794.0   14233.00
# 1          224453350      160.0                140.0  45030.0  143308.00
# 2             546000        0.0                  2.0   3304.0    5504.00
# 3          243395126       64.0                 24.0   9622.0   29871.00
# 4          305480000      202.0                148.0  59482.0  172810.64
#
#        Width  Doors  Seating_Capacity  Number_of_Airbags  Count           Avg
# 0   6179.000    8.0               8.0               22.0      3  3.626744e+07
# 1  56080.000  131.0             161.0              235.0     31  7.240431e+06
# 2   2624.000    8.0               8.0                0.0      2  2.730000e+05
# 3  12364.000   24.0              26.0               36.0      6  4.056585e+07
# 4  70017.845  157.0             170.0              261.0     37  8.256216e+06

# %%
sns.scatterplot(d1,x='Count',y='Avg')
# Out:
# <Axes: xlabel='Count', ylabel='Avg'>

# %% [markdown]
# ###Use pair plots for a quick overview of relationships between multiple numeric variables.

# %%
sns.pairplot(df)

# %% [markdown]
# The histogram on the diagonal allows us to see the distribution of a single variable while the scatter plots on the upper and lower triangles show the relationship (or lack thereof) between two variables.

# %% [markdown]
# ###Enhance bar charts by introducing the 'hue' parameter to represent additional categorical variables.

# %%
plot=sns.barplot(df,x='Make',y='Ex-Showroom_Price',hue='Fuel_Type')
plot.set_xticklabels(plot.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Tata'),
#  Text(1, 0, 'Datsun'),
#  Text(2, 0, 'Renault'),
#  Text(3, 0, 'Maruti Suzuki'),
#  Text(4, 0, 'Hyundai'),
#  Text(5, 0, 'Premier'),
#  Text(6, 0, 'Toyota'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Volkswagen'),
#  Text(9, 0, 'Ford'),
#  Text(10, 0, 'Mahindra'),
#  Text(11, 0, 'Fiat'),
#  Text(12, 0, 'Honda'),
#  Text(13, 0, 'Jeep'),
#  Text(14, 0, 'Isuzu'),
#  Text(15, 0, 'Skoda'),
#  Text(16, 0, 'Audi'),
#  Text(17, 0, 'Mercedes-Benz'),
#  Text(18, 0, 'Dc'),
#  Text(19, 0, 'Mini'),
#  Text(20, 0, 'Volvo'),
#  Text(21, 0, 'Jaguar'),
#  Text(22, 0, 'Bmw'),
#  Text(23, 0, 'Land Rover'),
#  Text(24, 0, 'Porsche'),
#  Text(25, 0, 'Lexus'),
#  Text(26, 0, 'Maserati'),
#  Text(27, 0, 'Lamborghini'),
#  Text(28, 0, 'Bentley'),
#  Text(29, 0, 'Ferrari'),
#  Text(30, 0, 'Aston Martin'),
#  Text(31, 0, 'Rolls-Royce'),
#  Text(32, 0, 'Bugatti'),
#  Text(33, 0, 'Bajaj'),
#  Text(34, 0, 'Icml'),
#  Text(35, 0, 'Force'),
#  Text(36, 0, 'Mg'),
#  Text(37, 0, 'Kia'),
# ...

# %% [markdown]
# ###Use joint plots to display the distribution of two numeric variables and their relationship.

# %%
sns.jointplot(df,x='Cylinders',y='Ex-Showroom_Price')

# %%
plot=sns.catplot(df,x='Fuel_Type',y='Ex-Showroom_Price')
